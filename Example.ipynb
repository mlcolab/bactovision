# %% [markdown]
# # Imports

# %%
from bactovision.widget import BactoWidget

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Annotate

# %%
widget = BactoWidget('data/bacterial-interaction-ex1.png')

# %%
widget
# Out:
# BactoWidget(children=(HBox(children=(VBox(children=(VBox(children=(HBox(children=(ToggleButton(value=False, de…

# %% [markdown]
# # Double-check the results if needed

# %%
result = widget.get_metrics()

# %%
plt.imshow(result['intergal_opacity'])
plt.colorbar()

# %%
plt.imshow(result['average_opacity'])
plt.colorbar()

# %%
plt.imshow(result['relative_area'])
plt.colorbar()

# %% [markdown]
# # Save results

# %%
np.savetxt('path-to-file-averate-opacity.csv', result['average_opacity'], delimiter=',')
